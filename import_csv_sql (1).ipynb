# %%
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import psycopg2
import sqlite3

# %%
engine = 'postgresql://postgres:mnbvcxz1234567@35.154.31.65:5432/generic_db_ii' #SM-DB

# %%
import os
#os.chdir(r"D:\Sociometrik\update_db_with_green_s_and_b_up")
df=pd.read_csv("GS_Density_Hexgrid08_94_Cities_raw.csv")
df=df.rename(columns=str.lower)
df
# Out:
#                hexid08  postcode            is_tc     t_name          is_sdc  \
# 0      883d34ac97fffff    192121  IND001010800013   Srinagar  IND00100200008
# 1      883d34a63dfffff    191131  IND001010800013   Srinagar  IND00101100047
# 2      883d34a483fffff    190003  IND001010800013   Srinagar  IND00101000044
# 3      883d35d317fffff    190006  IND001010800013   Srinagar  IND00101100047
# 4      883d35d31dfffff    190006  IND001010800013   Srinagar  IND00101100047
# ...                ...       ...              ...        ...             ...
# 67888  8860a24b5dfffff    500084  IND036536802918  Hyderabad  IND03653704543
# 67889  8860a250b7fffff    501218  IND036536802918  Hyderabad  IND03653704543
# 67890  8860a25885fffff    500031  IND036536802918  Hyderabad  IND03653704543
# 67891  8860b52f31fffff    500088  IND036536802918  Hyderabad  IND03653704543
# 67892  8860b1b24bfffff    502300  IND036536802918  Hyderabad  IND03653504495
#
# ...

# %%
#or use uperone to read 
df = pd.read_csv(r'GS_Density_556Cities.csv‪', encoding = 'latin1', header = 0,)
df = df.rename(columns=str.lower)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [25], line 2
#       1 #or use uperone to read
# ----> 2 df = pd.read_csv(r'GS_Density_556Cities.csv‪', encoding = 'latin1', header = 0,)
#       3 df = df.rename(columns=str.lower)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
# ...

# %%
df
# Out:
#                hexid08  postcode            is_tc     t_name          is_sdc  \
# 0      883d34ac97fffff    192121  IND001010800013   Srinagar  IND00100200008
# 1      883d34a63dfffff    191131  IND001010800013   Srinagar  IND00101100047
# 2      883d34a483fffff    190003  IND001010800013   Srinagar  IND00101000044
# 3      883d35d317fffff    190006  IND001010800013   Srinagar  IND00101100047
# 4      883d35d31dfffff    190006  IND001010800013   Srinagar  IND00101100047
# ...                ...       ...              ...        ...             ...
# 67888  8860a24b5dfffff    500084  IND036536802918  Hyderabad  IND03653704543
# 67889  8860a250b7fffff    501218  IND036536802918  Hyderabad  IND03653704543
# 67890  8860a25885fffff    500031  IND036536802918  Hyderabad  IND03653704543
# 67891  8860b52f31fffff    500088  IND036536802918  Hyderabad  IND03653704543
# 67892  8860b1b24bfffff    502300  IND036536802918  Hyderabad  IND03653504495
#
# ...

# %%
df.to_sql(name='for_upadate_green_space_inhex', con=engine, schema='raw_data', if_exists = 'fail', index=False) #replace, append
# Out:
# 893
