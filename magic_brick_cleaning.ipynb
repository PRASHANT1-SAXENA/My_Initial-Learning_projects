# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\chemi\Desktop\save_csv\‪magic_bricks_all_cities.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134201 entries, 0 to 134200
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   unique_id         134201 non-null  int64
#  1   City              134201 non-null  object
#  2   Rent_price        130347 non-null  float64
#  3   CarpetArea        49877 non-null   float64
#  4   CarpetUnit        49877 non-null   object
#  5   CoveredArea       123831 non-null  object
#  6   CoveredUnit       123831 non-null  object
#  7   latitude          124401 non-null  float64
#  8   longitude         124401 non-null  float64
#  9   Post_date         134201 non-null  object
#  10  Property_Name     134201 non-null  object
#  11  Property_Address  134127 non-null  object
#  12  url               134201 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
df2=df.copy(deep=True)

# %%
df2=df2[df2["Rent_price"].isnull()==False]
df2=df2[df2["latitude"].isnull()==False]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120768 entries, 0 to 134200
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   unique_id         120768 non-null  int64
#  1   City              120768 non-null  object
#  2   Rent_price        120768 non-null  float64
#  3   CarpetArea        44713 non-null   float64
#  4   CarpetUnit        44713 non-null   object
#  5   CoveredArea       113699 non-null  object
#  6   CoveredUnit       113699 non-null  object
#  7   latitude          120768 non-null  float64
#  8   longitude         120768 non-null  float64
#  9   Post_date         120768 non-null  object
#  10  Property_Name     120768 non-null  object
#  11  Property_Address  120701 non-null  object
#  12  url               120768 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 12.9+ MB

# %%
df2.iloc[330:340]
# Out:
#      unique_id       City  Rent_price  CarpetArea CarpetUnit CoveredArea  \
# 374   59478527       Agra     14000.0      1450.0      Sq-ft        1550
# 375   64993171       Agra     13000.0       130.0      Sq-ft         130
# 376   50286198  Ahmedabad     22000.0      1249.0      Sq-ft        1785
# 377   64667767  Ahmedabad     35000.0       290.0      Sq-ft         363
# 378   62251309  Ahmedabad     18000.0         NaN        NaN        1113
# 379   62052561  Ahmedabad     15000.0       756.0      Sq-ft        1260
# 380   59314583  Ahmedabad     20000.0         NaN        NaN        1365
# 381   63757325  Ahmedabad     60000.0      1566.0      Sq-ft        2610
# 382   62084423  Ahmedabad    450000.0      3882.0      Sq-ft        5881
# 383   64862625  Ahmedabad     45000.0       195.0      Sq-ft         300
#
#     CoveredUnit   latitude  longitude   Post_date  \
# 374       Sq-ft  27.200579  77.944595  11-12-2022
# 375       Sq-ft  27.157556  78.033094  06-01-2023
# ...

# %%
df2.reset_index(inplace=True)

# %%
df2.drop(columns="index",inplace=True)

# %%
df2["City"].nunique()

# %%
df2["CoveredArea"]=df2["CoveredArea"].astype(str).str.replace(",", "").astype(float)

# %%
# to replace the null value of coveredarea with carpetarea
for i,j in enumerate(df2["CoveredArea"]):
    if df2["CoveredArea"][i].astype(str)=="nan"and df2["CarpetArea"][i].astype(str)!="nan":
        df2["CoveredArea"][i]=df2["CarpetArea"][i]
        df2["CoveredUnit"][i]=df2["CarpetUnit"][i]
# Out:
# C:\Users\chemi\AppData\Local\Temp\ipykernel_35476\922023373.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["CoveredArea"][i]=df2["CarpetArea"][i]
# C:\Users\chemi\AppData\Local\Temp\ipykernel_35476\922023373.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["CoveredUnit"][i]=df2["CarpetUnit"][i]

# %%
#df2.drop(columns="CarpetArea",inplace=True)
df2.drop(columns="CarpetUnit",inplace=True)

# %%
df2.rename(columns={"CoveredArea":"property_area_sqft"},inplace=True)

# %%
df2=df2[df2["property_area_sqft"].isnull()==False]

# %%
#df2.to_csv(r'C:\Users\chemi\Desktop\save_csv\magicbrick_cleaned.csv')

# %%
#remove some rent price manually which have give rent for call on website link

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# cleaning part 2

# %%
clean_mgb=pd.read_csv(r"C:\Users\chemi\Desktop\save_csv\magicbrick_cleaned.csv")

# %%
clean_mgb
# Out:
#         unique_id      City  Rent_price  property_area_sqft CoveredUnit  \
# 0        65067887      Agra     5000000                1350       Sq-ft
# 1        27488515      Agra     4500000                1450       Sq-ft
# 2        64395181      Agra       60000                 225       Sq-ft
# 3        33106779      Agra       58000                3500       Sq-ft
# 4        54838709      Agra       50000                2765       Sq-ft
# ...           ...       ...         ...                 ...         ...
# 120559   63201363  Warangal        5000                 750       Sq-ft
# 120560   64092817  Warangal        5000                   1       Sq-ft
# 120561   63164889  Warangal        4500                 450       Sq-ft
# 120562   48954757  Warangal        4200                 400       Sq-ft
# 120563   58423201  Warangal        4000                2025       Sq-ft
#
#          latitude  longitude   Post_date  \
# 0       27.217419  77.950218  11-01-2023
# ...

# %%
#limit "property_area_sqft" between 50 to 10001
clean_mgb=clean_mgb[clean_mgb["property_area_sqft"].between(50,10001)]

# %%
#plt.figure(figsize=(10,20))
#clean_mgb[["Rent_price","property_area_sqft"]].plot(kind="box")
#clean_mgb["property_area_sqft"].plot(kind="box")
#plt.show()

# %%
clean_mgb.to_csv(r"C:\Users\chemi\Desktop\save_csv\Magicbricks_updated.csv")
