# %%
#importing the necessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
data=pd.read_csv("AirPassengers.csv")

# %%
#EDA on the time series data 
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
data.shape
# Out:
# (144, 2)

# %%
data.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %%
data['Month'] = pd.to_datetime(data['Month'])
data.index = data['Month']
del data['Month']

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
#plotting the time series
data.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
data.shape
# Out:
# (144, 1)

# %%
mean_log = data.rolling(window=12).mean()
std_log = data.rolling(window=12).std()

plt.plot(df,color='blue',label='Original')
plt.plot(mean_log, color='red', label='Rolling Mean')
plt.plot(std_log, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation (Logarithmic Scale)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 4
#       1 mean_log = data.rolling(window=12).mean()
#       2 std_log = data.rolling(window=12).std()
# ----> 4 plt.plot(df,color='blue',label='Original')
#       5 plt.plot(mean_log, color='red', label='Rolling Mean')
#       6 plt.plot(std_log, color='black', label='Rolling Std')
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\pyplot.py:2730, in plot(scalex, scaley, data, *args, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.plot)
#    2729 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2730     return gca().plot(
#    2731         *args, scalex=scalex, scaley=scaley,
#    2732         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\axes\_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
# --> 501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\axis.py:1608, in Axis.update_units(self, data)
#    1606 neednew = self.converter != converter
#    1607 self.converter = converter
# -> 1608 default = self.converter.default_units(data, self)
#    1609 if default is not None and self.units is None:
#    1610     self.set_units(default)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\category.py:116, in StrCategoryConverter.default_units(data, axis)
#     114 # the conversion call stack is default_units -> axis_info -> convert
#     115 if axis.units is None:
# --> 116     axis.set_units(UnitData(data))
#     117 else:
#     118     axis.units.update(data)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\category.py:192, in UnitData.__init__(self, data)
#     190 self._counter = itertools.count()
#     191 if data is not None:
# --> 192     self.update(data)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\matplotlib\category.py:225, in UnitData.update(self, data)
#     223 # check if convertible to number:
#     224 convertible = True
# --> 225 for val in OrderedDict.fromkeys(data):
#     226     # OrderedDict just iterates over unique values in data.
#     227     _api.check_isinstance((str, bytes), value=val)
#     228     if convertible:
#     229         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'numpy.ndarray'

# %% [markdown]
# Before building a time series model, we need to make sure that the time series is stationary. If the time series is non-stationary, then we need to make it stationary by differencing the data. The number of times we take a difference of the data is a parameter used in ARIMA models, which we will see shortly.
#
# Non-stationarity in time series may appear for the following reasons:
#
# Presence of a trend in the data
# Presence of heteroskedasticity
# Presence of autocorrelation
# We can identify non-stationarity in the time series by performing a statistical test called the Augmented Dicky-Fuller Test.
#
# Null Hypothesis: The time series is non stationary
# Alternate Hypothesis: The time series is stationary

# %%
#checking the stationarity of the series 
from statsmodels.tsa.stattools import adfuller
result = adfuller(data['#Passengers'])
print(result)
# Out:
# (0.8153688792060482, 0.991880243437641, 13, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 996.692930839019)

# %%
#logrithmic comutation to make the time series stationary
first_log = np.log(data)
first_log = first_log.dropna()
first_log.plot()
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
mean_log = first_log.rolling(window=12).mean()
std_log = first_log.rolling(window=12).std()

plt.plot(first_log, color='blue', label='Original')
plt.plot(mean_log, color='red', label='Rolling Mean')
plt.plot(std_log, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation (Logarithmic Scale)')
# Out:
# Text(0.5, 1.0, 'Rolling Mean & Standard Deviation (Logarithmic Scale)')

# %%
new_data = first_log - mean_log
new_data = new_data.dropna()
new_data.head()
# Out:
#             #Passengers
# Month
# 1949-12-01    -0.065494
# 1950-01-01    -0.093449
# 1950-02-01    -0.007566
# 1950-03-01     0.099416
# 1950-04-01     0.052142

# %%
#adfuller test for stationarity
result = adfuller(new_data['#Passengers'])
print(result)
# Out:
# (-3.162907991300869, 0.022234630001243157, 13, 119, {'1%': -3.4865346059036564, '5%': -2.8861509858476264, '10%': -2.579896092790057}, -436.63269481747034)

# %%
mean_log = new_data.rolling(window=12).mean()
std_log = new_data.rolling(window=12).std()

plt.plot(new_data, color='blue', label='Original')
plt.plot(mean_log, color='red', label='Rolling Mean')
plt.plot(std_log, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation (Logarithmic Scale)')
# Out:
# Text(0.5, 1.0, 'Rolling Mean & Standard Deviation (Logarithmic Scale)')

# %%
#seasonal Decompose
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_result = seasonal_decompose(data['#Passengers'].dropna())

decompose_result.plot()

# %%
#seasonal Decompose
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_result = seasonal_decompose(new_data['#Passengers'].dropna())

decompose_result.plot()

# %% [markdown]
# ACF and PACF plots are used to identify the model's order in ARIMA models. These plots help to find the parameters p and q. Also, we always plot the ACF and PACF plots after making the time series stationary.

# %%
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
acf_plot=acf(new_data)
pacf_plot=pacf(new_data)
plot_acf(acf_plot)
plot_pacf(pacf_plot)
# Out:
# C:\Users\chemi\Desktop\enviroments\myml\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [38], line 8
#       6 pacf_plot=pacf(new_data)
#       7 plot_acf(acf_plot)
# ----> 8 plot_pacf(pacf_plot)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\statsmodels\graphics\tsaplots.py:363, in plot_pacf(x, ax, lags, alpha, method, use_vlines, title, zero, vlines_kwargs, **kwargs)
#     361     acf_x = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     362 else:
# --> 363     acf_x, confint = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     365 _plot_corr(
#     366     ax,
#     367     title,
#    (...)
#     374     **kwargs,
#     375 )
#     377 return fig
#
# File ~\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\stattools.py:996, in pacf(x, nlags, method, alpha)
#     994     nlags = min(int(10 * np.log10(nobs)), nobs // 2 - 1)
#     995 if nlags >= x.shape[0] // 2:
# --> 996     raise ValueError(
#     997         "Can only compute partial correlations for lags up to 50% of the "
#     998         f"sample size. The requested nlags {nlags} must be < "
#     999         f"{x.shape[0] // 2}."
#    1000     )
#    1002 if method in ("ols", "ols-inefficient", "ols-adjusted"):
#    1003     efficient = "inefficient" not in method
#
# ValueError: Can only compute partial correlations for lags up to 50% of the sample size. The requested nlags 14 must be < 11.

# %%
from statsmodels.tsa.arima_model import ARIMA

train = new_data.iloc[:120]['#Passengers']
test = new_data.iloc[121:]['#Passengers']

model = ARIMA(train, order=(1,0,2))
model_fit = model.fit()
model_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In [39], line 6
#       3 train = new_data.iloc[:120]['#Passengers']
#       4 test = new_data.iloc[121:]['#Passengers']
# ----> 6 model = ARIMA(train, order=(1,0,2))
#       7 model_fit = model.fit()
#       8 model_fit.summary()
#
# File ~\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\arima_model.py:45, in ARIMA.__init__(self, *args, **kwargs)
#      44 def __init__(self, *args, **kwargs):
# ---> 45     super().__init__(*args, **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\arima_model.py:29, in ARMA.__init__(self, *args, **kwargs)
#      28 def __init__(self, *args, **kwargs):
# ---> 29     raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and statsmodels.tsa.SARIMAX.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained. It also offers alternative specialized
# parameter estimators.

# %%
len(train)+len(test)- 1
# Out:
# 131

# %%
len(train)+len(test)- 1
# Out:
# 131

# %%
new_data['predict'] = model_fit.predict(start= len(train), 
                                    end=len(train)+len(test)- 1, 
                                    dynamic=True)
new_data[['#Passengers','predict']].plot()
# Arema model does not take seasonality into consideration so the model is shown ploting is not good so 
# now we SERMA model

# %%
    from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults

    model = SARIMAX(train, order=(1,0,2), seasonal_order=(1,0,2,12))
    model = model.fit()
# Out:
# C:\Users\chemi\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\chemi\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\chemi\Desktop\enviroments\myml\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\chemi\Desktop\enviroments\myml\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
new_data['predict'] = model.predict(start= len(train) ,
                                                       end=len(train)+len(test)- 1, 
                                                       dynamic=True)
new_data[['#Passengers','predict']].plot()

# %%
#predicting the projections for the next 5 years
forecast = model.forecast(steps=240)
new_data.plot()
forecast.plot()
