# %%
#import required packages
import fiona
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from pathlib import Path
import os
import numpy as np

# %%
indicator_name = 'Rental_Data'

# %% [markdown]
# ### Converting excel to point data file

# %%
# Reading file

file_path = r'Magicbrics_99_merged.csv'
pointDf = pd.read_csv(file_path,header=0)
pointDf.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 4
#       1 # Reading file
#       3 file_path = r'Magicbrics_99_merged.csv'
# ----> 4 pointDf = pd.read_csv(file_path,header=0)
#       5 pointDf.head()
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\io\parsers\readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~\Desktop\enviroments\myml\lib\site-packages\pandas\io\common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Magicbrics_99_merged.csv'

# %%
# Checking data types of attributes

pointDf.dtypes
# Out:
# Id                      int64
# city_search            object
# city                   object
# price                   int64
# property_area_sqft     object
# latitude              float64
# longitude             float64
# dtype: object

# %%
len(pointDf['property_area_sqft'])
# Out:
# 96260

# %%
# Snippet converts column data type to float format

pointDf['property_area_sqft'] = pointDf['property_area_sqft'].astype(str).str.replace(",", "").astype(float)
pointDf.dtypes
# Out:
# Id                      int64
# city_search            object
# city                   object
# price                   int64
# property_area_sqft    float64
# latitude              float64
# longitude             float64
# dtype: object

# %%
# pointDf.to_csv(r'D:\Pdt_V2.0\vector\rental_data\priceCheck.csv')

# %%
# Creating & adding geometry column from lat, lon attributes

# Ref - https://stdworkflow.com/1615/python-geopandas-text-latitude-and-longitude-converted-to-point-features-line-features

geometry = [Point(xy) for xy in zip(pointDf.longitude, pointDf.latitude)]
gdf = gpd.GeoDataFrame(pointDf, crs="EPSG:4326", geometry = geometry)
gdf
# Out:
#           Id city_search       city   price  property_area_sqft   latitude  \
# 0          1   Bangalore  Bangalore   38000          975.000000  13.034996
# 1          2   Bangalore  Bangalore    8500          750.000000  12.868307
# 2          3   Bangalore  Bangalore  250000         3900.000000  12.994704
# 3          4   Bangalore  Bangalore   16000         1200.000000  12.782255
# 4          5   Bangalore  Bangalore   57000         1540.000000  12.994704
# ...      ...         ...        ...     ...                 ...        ...
# 96255  37560      Mysore     Mysore    6000         1200.000000  12.352240
# 96256  37561      Mysore     Mysore   20000         1600.000000  12.307167
# 96257  37562      Mysore     Mysore   12000         1200.000000  12.312373
# 96258  37563      Mysore     Mysore   21000         1020.096229  12.259453
# 96259  37564      Mysore     Mysore   12000         1200.000000  12.276774
#
#        longitude                   geometry
# 0      77.598173  POINT (77.59817 13.03500)
# 1      77.621774  POINT (77.62177 12.86831)
# 2      77.551440  POINT (77.55144 12.99470)
# 3      77.645230  POINT (77.64523 12.78225)
# 4      77.551440  POINT (77.55144 12.99470)
# ...          ...                        ...
# 96255  76.608950  POINT (76.60895 12.35224)
# 96256  76.684829  POINT (76.68483 12.30717)
# 96257  76.695421  POINT (76.69542 12.31237)
# 96258  76.653928  POINT (76.65393 12.25945)
# 96259  76.644159  POINT (76.64416 12.27677)
#
# [96260 rows x 8 columns]

# %%
# Saving file

# output_path = r'D:\Pdt_V2\vector\rental_data\Rental_Cleaned' + '/' + Path(file_path).stem + '_shp/'

# if not os.path.exists(output_path):
#     os.makedirs(output_path)

gdf.to_file(filename = Path(file_path).stem + '.shp', driver = "ESRI Shapefile")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 8
#       1 # Saving file
#       2
#       3 # output_path = r'D:\Pdt_V2\vector\rental_data\Rental_Cleaned' + '/' + Path(file_path).stem + '_shp/'
#       4
#       5 # if not os.path.exists(output_path):
#       6 #     os.makedirs(output_path)
# ----> 8 gdf.to_file(filename = Path(file_path).stem + '.shp', driver = "ESRI Shapefile")
#
# NameError: name 'gdf' is not defined

# %% [markdown]
# ### Clipping to AOI extent

# %%
# Reading input file whose extent is to be taken 

aoi_file_path = r'Hexgrid_08_bomcities.shp'
aoi_file = gpd.read_file(aoi_file_path)
aoi_file.shape
# Out:
#                hexid08 postcode        is_tc_buf t_name_buf          is_sdc  \
# 0      883d8c2499fffff   226301  IND009157800951    Lucknow  IND00915700821
# 1      883d8c249bfffff   226301  IND009157800951    Lucknow  IND00915700821
# 2      883d8c24c9fffff   226401  IND009157800951    Lucknow  IND00915700821
# 3      883d8c24cbfffff   226401  IND009157800951    Lucknow  IND00915700821
# 4      883d8c24d1fffff   226401  IND009157800951    Lucknow  IND00915700821
# ...                ...      ...              ...        ...             ...
# 11845  8860060eadfffff   673028  IND032591803267  Kozhikode  IND03259105640
# 11846  8860060ee7fffff   673015  IND032591803267  Kozhikode  IND03259105640
# 11847  8860060721fffff   673314  IND032591803267  Kozhikode  IND03259205645
# 11848  8860060d95fffff   673005  IND032591803267  Kozhikode  IND03259105640
# 11849  8860067739fffff   673303  IND032591803267  Kozhikode  IND03259105640
#
#            is_dc      sd_name      d_name         s_name   is_sc  \
# 0      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 1      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 2      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 3      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 4      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# ...          ...          ...         ...            ...     ...
# 11845  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11846  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11847  IND032592  Tirurangadi  Malappuram         Kerala  IND032
# 11848  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11849  IND032591    Kozhikode   Kozhikode         Kerala  IND032
#
#             geohash                                           geometry
# 0      tu9xb79j7gbw  POLYGON ((80.86710 26.69702, 80.87178 26.69958...
# 1      tu9xbeb028uf  POLYGON ((80.87658 26.69752, 80.88126 26.70008...
# 2      tu9rzk9btqxk  POLYGON ((80.82425 26.70171, 80.82893 26.70427...
# 3      tu9rzs8gdkj1  POLYGON ((80.83373 26.70221, 80.83841 26.70478...
# 4      tu9rzuy9knxb  POLYGON ((80.85270 26.70321, 80.85738 26.70578...
# ...             ...                                                ...
# 11845  t9vzswfkmmmk  POLYGON ((75.79109 11.19744, 75.78696 11.19500...
# 11846  t9vzstt3516v  POLYGON ((75.79511 11.19000, 75.79098 11.18756...
# 11847  t9vzjevmmg1k  POLYGON ((75.83917 11.09323, 75.83504 11.09079...
# 11848  tdjb5vy0tn0r  POLYGON ((75.76326 11.27921, 75.75913 11.27676...
# 11849  tdjbe2sene12  POLYGON ((75.73929 11.33867, 75.73517 11.33623...
#
# [11850 rows x 12 columns]

# %%
# File to be clipped

input_file_path = Path(file_path).stem + '.shp' 
input_file = gpd.read_file(input_file_path)
input_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 # File to be clipped
# ----> 3 input_file_path = Path(file_path).stem + '.shp'
#       4 input_file = gpd.read_file(input_file_path)
#       5 input_file
#
# NameError: name 'Path' is not defined

# %%
# Clipping function

clip_file = gpd.clip(input_file, aoi_file)
clip_file
# Out:
#           Id city_searc            city  price  property_a   latitude  \
# 30529  34967    Lucknow         Lucknow   9500      1000.0  26.966376
# 28242  32531    Lucknow         Lucknow   9000      1004.0  26.966376
# 30366  34804    Lucknow         Lucknow  10000       807.0  26.966376
# 86516  27798    Lucknow         Lucknow  10000       908.0  26.966378
# 86037  27319    Lucknow         Lucknow   8000      1250.0  26.966378
# ...      ...        ...             ...    ...         ...        ...
# 24884  28724  Ahmedabad       Ahmedabad  25000       900.0  23.034523
# 80038  21305  Ahmedabad  Ahmedabad West  20000       990.0  23.034617
# 79839  21106  Ahmedabad  Ahmedabad West  65000      2007.0  23.034704
# 45826  52571  Ahmedabad       Ahmedabad  18000       231.0  23.034780
# 79564  20831  Ahmedabad  Ahmedabad West  25000      1150.0  23.034875
#
#        longitude                   geometry
# 30529  81.000609  POINT (81.00061 26.96638)
# 28242  81.000609  POINT (81.00061 26.96638)
# 30366  81.000609  POINT (81.00061 26.96638)
# 86516  81.002796  POINT (81.00280 26.96638)
# 86037  81.002796  POINT (81.00280 26.96638)
# ...          ...                        ...
# 24884  72.530637  POINT (72.53064 23.03452)
# 80038  72.531406  POINT (72.53141 23.03462)
# 79839  72.562620  POINT (72.56262 23.03470)
# 45826  72.542780  POINT (72.54278 23.03478)
# 79564  72.580120  POINT (72.58012 23.03487)
#
# [77189 rows x 8 columns]

# %%
clip_file.dtypes
# Out:
# Id               int64
# city_searc      object
# city            object
# price            int64
# property_a     float64
# latitude       float64
# longitude      float64
# geometry      geometry
# dtype: object

# %%
clip_out_path = r'D:\Pdt_V2\vector\rental_data\Rental_Cleaned' + '/' + Path(input_file_path).stem + '_clip'

if not os.path.exists(clip_out_path):
    os.makedirs(clip_out_path)

clip_file.to_file(filename = clip_out_path +  '/' + Path(input_file_path).stem + '_' + Path(aoi_file_path).stem + \
                  '.shp', driver = "ESRI Shapefile")

# %% [markdown]
# ### Calculating Price per sqft

# %%
df = clip_file.copy()
df['Price_per_sqft'] = df['price']/df['property_a']
df
# Out:
#           Id city_searc            city  price  property_a   latitude  \
# 30529  34967    Lucknow         Lucknow   9500      1000.0  26.966376
# 28242  32531    Lucknow         Lucknow   9000      1004.0  26.966376
# 30366  34804    Lucknow         Lucknow  10000       807.0  26.966376
# 86516  27798    Lucknow         Lucknow  10000       908.0  26.966378
# 86037  27319    Lucknow         Lucknow   8000      1250.0  26.966378
# ...      ...        ...             ...    ...         ...        ...
# 24884  28724  Ahmedabad       Ahmedabad  25000       900.0  23.034523
# 80038  21305  Ahmedabad  Ahmedabad West  20000       990.0  23.034617
# 79839  21106  Ahmedabad  Ahmedabad West  65000      2007.0  23.034704
# 45826  52571  Ahmedabad       Ahmedabad  18000       231.0  23.034780
# 79564  20831  Ahmedabad  Ahmedabad West  25000      1150.0  23.034875
#
#        longitude                   geometry  Price_per_sqft
# 30529  81.000609  POINT (81.00061 26.96638)        9.500000
# 28242  81.000609  POINT (81.00061 26.96638)        8.964143
# 30366  81.000609  POINT (81.00061 26.96638)       12.391574
# 86516  81.002796  POINT (81.00280 26.96638)       11.013216
# 86037  81.002796  POINT (81.00280 26.96638)        6.400000
# ...          ...                        ...             ...
# 24884  72.530637  POINT (72.53064 23.03452)       27.777778
# 80038  72.531406  POINT (72.53141 23.03462)       20.202020
# 79839  72.562620  POINT (72.56262 23.03470)       32.386647
# 45826  72.542780  POINT (72.54278 23.03478)       77.922078
# 79564  72.580120  POINT (72.58012 23.03487)       21.739130
#
# [77189 rows x 9 columns]

# %% [markdown]
# ### Aggregating data at AOI level

# %%
# The columns to be summed over  

price_column = 'Price_per_sqft'

# %%
raw_file = df[['price', 'property_a', price_column, 'geometry']]
raw_file
# Out:
#        price  property_a  Price_per_sqft                   geometry
# 30529   9500      1000.0        9.500000  POINT (81.00061 26.96638)
# 28242   9000      1004.0        8.964143  POINT (81.00061 26.96638)
# 30366  10000       807.0       12.391574  POINT (81.00061 26.96638)
# 86516  10000       908.0       11.013216  POINT (81.00280 26.96638)
# 86037   8000      1250.0        6.400000  POINT (81.00280 26.96638)
# ...      ...         ...             ...                        ...
# 24884  25000       900.0       27.777778  POINT (72.53064 23.03452)
# 80038  20000       990.0       20.202020  POINT (72.53141 23.03462)
# 79839  65000      2007.0       32.386647  POINT (72.56262 23.03470)
# 45826  18000       231.0       77.922078  POINT (72.54278 23.03478)
# 79564  25000      1150.0       21.739130  POINT (72.58012 23.03487)
#
# [77189 rows x 4 columns]

# %%
agg_out_path = r'D:\Pdt_V2\outputs' + '/' + indicator_name + '/AveragePriceSqft/' 

if not os.path.exists(agg_out_path):
    os.makedirs(agg_out_path)

# %%
# File with raw data

data_join_csv = gpd.sjoin(aoi_file, raw_file, how="left", op='intersects').drop(['index_right'], axis=1)
data_join_csv = data_join_csv.drop(['geometry'], axis = 1)

data_join_csv.to_csv(agg_out_path +  '/' + Path(input_file_path).stem + '_' + Path(aoi_file_path).stem + '_raw.csv',index=False)

data_join_csv
# Out:
# C:\Program Files\Python39\lib\site-packages\IPython\core\interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#                HEXID08 POSTCODE        IS_TC_BUF T_NAME_BUF          IS_SDC  \
# 0      883d8c2499fffff   226301  IND009157800951    Lucknow  IND00915700821
# 1      883d8c249bfffff   226301  IND009157800951    Lucknow  IND00915700821
# 2      883d8c24c9fffff   226401  IND009157800951    Lucknow  IND00915700821
# 3      883d8c24cbfffff   226401  IND009157800951    Lucknow  IND00915700821
# 4      883d8c24d1fffff   226401  IND009157800951    Lucknow  IND00915700821
# ...                ...      ...              ...        ...             ...
# 11845  8860060eadfffff   673028  IND032591803267  Kozhikode  IND03259105640
# 11846  8860060ee7fffff   673015  IND032591803267  Kozhikode  IND03259105640
# 11847  8860060721fffff   673314  IND032591803267  Kozhikode  IND03259205645
# 11848  8860060d95fffff   673005  IND032591803267  Kozhikode  IND03259105640
# 11849  8860067739fffff   673303  IND032591803267  Kozhikode  IND03259105640
#
#            IS_DC      SD_NAME      D_NAME         S_NAME   IS_SC  \
# 0      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 1      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 2      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 3      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 4      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# ...          ...          ...         ...            ...     ...
# 11845  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11846  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11847  IND032592  Tirurangadi  Malappuram         Kerala  IND032
# 11848  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11849  IND032591    Kozhikode   Kozhikode         Kerala  IND032
#
#             GEOHASH  price  property_a  Price_per_sqft
# 0      tu9xb79j7gbw    NaN         NaN             NaN
# 1      tu9xbeb028uf    NaN         NaN             NaN
# 2      tu9rzk9btqxk    NaN         NaN             NaN
# 3      tu9rzs8gdkj1    NaN         NaN             NaN
# 4      tu9rzuy9knxb    NaN         NaN             NaN
# ...             ...    ...         ...             ...
# 11845  t9vzswfkmmmk    NaN         NaN             NaN
# 11846  t9vzstt3516v    NaN         NaN             NaN
# 11847  t9vzjevmmg1k    NaN         NaN             NaN
# 11848  tdjb5vy0tn0r    NaN         NaN             NaN
# 11849  tdjbe2sene12    NaN         NaN             NaN
#
# [85369 rows x 14 columns]

# %%
price_file = df[[price_column, 'geometry']]
price_file
# Out:
#        Price_per_sqft                   geometry
# 30529        9.500000  POINT (81.00061 26.96638)
# 28242        8.964143  POINT (81.00061 26.96638)
# 30366       12.391574  POINT (81.00061 26.96638)
# 86516       11.013216  POINT (81.00280 26.96638)
# 86037        6.400000  POINT (81.00280 26.96638)
# ...               ...                        ...
# 24884       27.777778  POINT (72.53064 23.03452)
# 80038       20.202020  POINT (72.53141 23.03462)
# 79839       32.386647  POINT (72.56262 23.03470)
# 45826       77.922078  POINT (72.54278 23.03478)
# 79564       21.739130  POINT (72.58012 23.03487)
#
# [77189 rows x 2 columns]

# %%
# Spatial join to obtain points falling within each boundary polygons 
# how parameter set to "left" to retain polygons which has no points in rental data file

data_join = gpd.sjoin(aoi_file, price_file, how="left", op='intersects').drop(['index_right'], axis=1)

data_join
# Out:
# C:\Program Files\Python39\lib\site-packages\IPython\core\interactiveshell.py:3373: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#                HEXID08 POSTCODE        IS_TC_BUF T_NAME_BUF          IS_SDC  \
# 0      883d8c2499fffff   226301  IND009157800951    Lucknow  IND00915700821
# 1      883d8c249bfffff   226301  IND009157800951    Lucknow  IND00915700821
# 2      883d8c24c9fffff   226401  IND009157800951    Lucknow  IND00915700821
# 3      883d8c24cbfffff   226401  IND009157800951    Lucknow  IND00915700821
# 4      883d8c24d1fffff   226401  IND009157800951    Lucknow  IND00915700821
# ...                ...      ...              ...        ...             ...
# 11845  8860060eadfffff   673028  IND032591803267  Kozhikode  IND03259105640
# 11846  8860060ee7fffff   673015  IND032591803267  Kozhikode  IND03259105640
# 11847  8860060721fffff   673314  IND032591803267  Kozhikode  IND03259205645
# 11848  8860060d95fffff   673005  IND032591803267  Kozhikode  IND03259105640
# 11849  8860067739fffff   673303  IND032591803267  Kozhikode  IND03259105640
#
#            IS_DC      SD_NAME      D_NAME         S_NAME   IS_SC  \
# 0      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 1      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 2      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 3      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# 4      IND009157      Lucknow     Lucknow  Uttar Pradesh  IND009
# ...          ...          ...         ...            ...     ...
# 11845  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11846  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11847  IND032592  Tirurangadi  Malappuram         Kerala  IND032
# 11848  IND032591    Kozhikode   Kozhikode         Kerala  IND032
# 11849  IND032591    Kozhikode   Kozhikode         Kerala  IND032
#
#             GEOHASH                                           geometry  \
# 0      tu9xb79j7gbw  POLYGON ((80.86710 26.69702, 80.87178 26.69958...
# 1      tu9xbeb028uf  POLYGON ((80.87658 26.69752, 80.88126 26.70008...
# 2      tu9rzk9btqxk  POLYGON ((80.82425 26.70171, 80.82893 26.70427...
# 3      tu9rzs8gdkj1  POLYGON ((80.83373 26.70221, 80.83841 26.70478...
# 4      tu9rzuy9knxb  POLYGON ((80.85270 26.70321, 80.85738 26.70578...
# ...             ...                                                ...
# 11845  t9vzswfkmmmk  POLYGON ((75.79109 11.19744, 75.78696 11.19500...
# 11846  t9vzstt3516v  POLYGON ((75.79511 11.19000, 75.79098 11.18756...
# 11847  t9vzjevmmg1k  POLYGON ((75.83917 11.09323, 75.83504 11.09079...
# 11848  tdjb5vy0tn0r  POLYGON ((75.76326 11.27921, 75.75913 11.27676...
# 11849  tdjbe2sene12  POLYGON ((75.73929 11.33867, 75.73517 11.33623...
#
#        Price_per_sqft
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 11845             NaN
# 11846             NaN
# 11847             NaN
# 11848             NaN
# 11849             NaN
#
# [85369 rows x 13 columns]

# %%
# Adding a new attribute 'num_point' which can be later used for obtaining statistics on the no: of points in each polygon
# num_point set to 1 for rows containing data points


# has_point = data_join.loc[data_join[price_column].notnull()]
# has_point['num_point'] = 1
# has_point

# %%
# num_point set to 0 for rows having no data points

# no_point = data_join.loc[data_join[price_column].isnull()]
# no_point['num_point'] = 0
# no_point

# %%
# len(no_point.index)
# Out:
# 60

# %%
# Merging the rows back to a single data frame

# merged_list = [has_point, no_point]
# data_merged = pd.concat(merged_list)
# data_merged

# %%
# To check if the attribute values of columns are same for the rows with same HEXID

print(len(data_join.loc[data_join['HEXID08'] == '8860067739fffff']))
data_join.loc[data_join['HEXID08'] == '8860067739fffff']
# Out:
# 1
#                HEXID08 POSTCODE        IS_TC_BUF T_NAME_BUF          IS_SDC  \
# 11849  8860067739fffff   673303  IND032591803267  Kozhikode  IND03259105640
#
#            IS_DC    SD_NAME     D_NAME  S_NAME   IS_SC       GEOHASH  \
# 11849  IND032591  Kozhikode  Kozhikode  Kerala  IND032  tdjbe2sene12
#
#                                                 geometry  Price_per_sqft
# 11849  POLYGON ((75.73929 11.33867, 75.73517 11.33623...             NaN

# %%
# Creating dict of columns and their aggregation parameter

merged_columns = data_join.columns
merged_columns = merged_columns.drop([price_column]) #, 'num_point'
print('length: ', len(merged_columns))
print(merged_columns)
# Out:
# length:  12
# Index(['HEXID08', 'POSTCODE', 'IS_TC_BUF', 'T_NAME_BUF', 'IS_SDC', 'IS_DC',
#        'SD_NAME', 'D_NAME', 'S_NAME', 'IS_SC', 'GEOHASH', 'geometry'],
#       dtype='object')

# %%
column_list = {column:'first' for column in merged_columns}
column_list
# Out:
# {'HEXID08': 'first',
#  'POSTCODE': 'first',
#  'IS_TC_BUF': 'first',
#  'T_NAME_BUF': 'first',
#  'IS_SDC': 'first',
#  'IS_DC': 'first',
#  'SD_NAME': 'first',
#  'D_NAME': 'first',
#  'S_NAME': 'first',
#  'IS_SC': 'first',
#  'GEOHASH': 'first',
#  'geometry': 'first'}

# %%
# Assigning 'sum' as aggregation parameter for 'price_column' & total_area' attributes

column_list[price_column] = 'mean'
# column_list['num_point'] = 'sum'
column_list
# Out:
# {'HEXID08': 'first',
#  'POSTCODE': 'first',
#  'IS_TC_BUF': 'first',
#  'T_NAME_BUF': 'first',
#  'IS_SDC': 'first',
#  'IS_DC': 'first',
#  'SD_NAME': 'first',
#  'D_NAME': 'first',
#  'S_NAME': 'first',
#  'IS_SC': 'first',
#  'GEOHASH': 'first',
#  'geometry': 'first',
#  'Price_per_sqft': 'mean'}

# %%
count_nan_price = data_join[price_column].isnull().sum()
print(f'count_nan_price: {count_nan_price}')
# count_nan_area = data_join['total_area'].isnull().sum()
# print(f'count_nan_area: {count_nan_area}')
# Out:
# count_nan_price: 8180

# %%
# data_join[price_column] = data_join[price_column].fillna(0)
# data_join['total_area'] = data_join['total_area'].fillna(0)

# %%
# data_merged[price_column] = data_merged[price_column].fillna(0)

# data_join[price_column] = data_join[price_column].dropna()
# data_join

# %%
# Aggregating data by HEXID and summing price value at grid level

agg_data = data_join.groupby('HEXID08', as_index= False, dropna=True).agg(column_list) 
agg_data
# Out:
#                HEXID08 POSTCODE        IS_TC_BUF T_NAME_BUF          IS_SDC  \
# 0      883d8c2499fffff   226301  IND009157800951    Lucknow  IND00915700821
# 1      883d8c249bfffff   226301  IND009157800951    Lucknow  IND00915700821
# 2      883d8c24c9fffff   226401  IND009157800951    Lucknow  IND00915700821
# 3      883d8c24cbfffff   226401  IND009157800951    Lucknow  IND00915700821
# 4      883d8c24d1fffff   226401  IND009157800951    Lucknow  IND00915700821
# ...                ...      ...              ...        ...             ...
# 11845  88618935b9fffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11846  88618935bbfffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11847  88618935bdfffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11848  88618935d3fffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11849  88618935d7fffff   560099  IND029572803162  Bengaluru  IND02957205545
#
#            IS_DC  SD_NAME     D_NAME         S_NAME   IS_SC       GEOHASH  \
# 0      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9xb79j7gbw
# 1      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9xbeb028uf
# 2      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzk9btqxk
# 3      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzs8gdkj1
# 4      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzuy9knxb
# ...          ...      ...        ...            ...     ...           ...
# 11845  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr304pceqjf
# 11846  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr30419yvny
# 11847  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr3077j0wme
# 11848  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr2bhx7pqwj
# 11849  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr2bmfwswve
#
#                                                 geometry  Price_per_sqft
# 0      POLYGON ((80.86710 26.69702, 80.87178 26.69958...             NaN
# 1      POLYGON ((80.87658 26.69752, 80.88126 26.70008...             NaN
# 2      POLYGON ((80.82425 26.70171, 80.82893 26.70427...             NaN
# 3      POLYGON ((80.83373 26.70221, 80.83841 26.70478...             NaN
# 4      POLYGON ((80.85270 26.70321, 80.85738 26.70578...             NaN
# ...                                                  ...             ...
# 11845  POLYGON ((77.71028 12.84079, 77.70602 12.83832...             NaN
# 11846  POLYGON ((77.70184 12.84083, 77.69759 12.83835...             NaN
# 11847  POLYGON ((77.71462 12.84826, 77.71036 12.84578...             NaN
# 11848  POLYGON ((77.70976 12.81084, 77.70550 12.80836...             NaN
# 11849  POLYGON ((77.71411 12.81831, 77.70985 12.81583...       10.962963
#
# [11850 rows x 13 columns]

# %%
agg_data.columns
# Out:
# Index(['HEXID08', 'POSTCODE', 'IS_TC_BUF', 'T_NAME_BUF', 'IS_SDC', 'IS_DC',
#        'SD_NAME', 'D_NAME', 'S_NAME', 'IS_SC', 'GEOHASH', 'geometry',
#        'Price_per_sqft'],
#       dtype='object')

# %%
agg_data.dtypes
# Out:
# HEXID08             object
# POSTCODE            object
# IS_TC_BUF           object
# T_NAME_BUF          object
# IS_SDC              object
# IS_DC               object
# SD_NAME             object
# D_NAME              object
# S_NAME              object
# IS_SC               object
# GEOHASH             object
# geometry          geometry
# Price_per_sqft     float64
# dtype: object

# %%
len(agg_data['HEXID08'].unique())
# Out:
# 11850

# %%
agg_data.shape
# Out:
# (11850, 13)

# %%
agg_data_shp = agg_data.set_geometry('geometry')

agg_data_shp.to_file(filename = agg_out_path +  '/' + Path(input_file_path).stem + '_' + Path(aoi_file_path).stem + '_AvgpriceSqft.shp', 
                     driver = "ESRI Shapefile")
# Out:
# C:\Users\anubhav\AppData\Local\Temp\ipykernel_12308\193491690.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   agg_data_shp.to_file(filename = agg_out_path +  '/' + Path(input_file_path).stem + '_' + Path(aoi_file_path).stem + '_AvgpriceSqft.shp',

# %%
agg_data_csv = agg_data.drop(['geometry'], axis = 1)
agg_data_csv
# Out:
#                HEXID08 POSTCODE        IS_TC_BUF T_NAME_BUF          IS_SDC  \
# 0      883d8c2499fffff   226301  IND009157800951    Lucknow  IND00915700821
# 1      883d8c249bfffff   226301  IND009157800951    Lucknow  IND00915700821
# 2      883d8c24c9fffff   226401  IND009157800951    Lucknow  IND00915700821
# 3      883d8c24cbfffff   226401  IND009157800951    Lucknow  IND00915700821
# 4      883d8c24d1fffff   226401  IND009157800951    Lucknow  IND00915700821
# ...                ...      ...              ...        ...             ...
# 11845  88618935b9fffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11846  88618935bbfffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11847  88618935bdfffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11848  88618935d3fffff   560099  IND029572803162  Bengaluru  IND02957205545
# 11849  88618935d7fffff   560099  IND029572803162  Bengaluru  IND02957205545
#
#            IS_DC  SD_NAME     D_NAME         S_NAME   IS_SC       GEOHASH  \
# 0      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9xb79j7gbw
# 1      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9xbeb028uf
# 2      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzk9btqxk
# 3      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzs8gdkj1
# 4      IND009157  Lucknow    Lucknow  Uttar Pradesh  IND009  tu9rzuy9knxb
# ...          ...      ...        ...            ...     ...           ...
# 11845  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr304pceqjf
# 11846  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr30419yvny
# 11847  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr3077j0wme
# 11848  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr2bhx7pqwj
# 11849  IND029572   Anekal  Bangalore      Karnataka  IND029  tdr2bmfwswve
#
#        Price_per_sqft
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 11845             NaN
# 11846             NaN
# 11847             NaN
# 11848             NaN
# 11849       10.962963
#
# [11850 rows x 12 columns]

# %%
agg_data_csv.to_csv(agg_out_path +  '/' + Path(input_file_path).stem + '_' + Path(aoi_file_path).stem + '_AvgpriceSqft.csv',index=False)

# %%
# agg_data.loc[agg_data['num_point']==0]

# %%
# agg_data['num_point'].unique()
# Out:
# array([  0,   1,   3,   4,   2,  10,  43,  16,  14,   5,   6,   7,   8,
#         26,  23,  19,  40,  17,  12,   9,  63,  35,  13,  18,  20,  37,
#         28,  48,  15,  42,  44,  46,  22,  24,  45,  11,  34,  27,  64,
#         53,  21, 272,  41,  38,  25,  31,  32,  93,  29,  33,  62,  36,
#        140,  39,  55,  51,  47,  81,  61,  80,  87,  30,  50,  54,  68,
#         74,  96,  59, 183, 129, 105,  58,  99, 198,  70], dtype=int64)

# %%
# Calculating statistics of poygons - represents frequencies of the unique values in 'num_point' column

# stat_percent = agg_data['num_point'].value_counts(normalize=True)*100
# stat_percent = stat_percent.sort_index()
# print(type(stat_percent))
# stat_percent
# Out:
# <class 'pandas.core.series.Series'>
# 0      46.012592
# 1       8.342078
# 2       5.089192
# 3       4.459601
# 4       4.459601
#          ...
# 129     0.052466
# 140     0.052466
# 183     0.052466
# 198     0.052466
# 272     0.052466
# Name: num_point, Length: 75, dtype: float64

# %%
# Calculating statistics of poygons - represents number of polygons having the unique values in 'num_point' column

# stat_num = agg_data['num_point'].value_counts()
# stat_num = stat_num.sort_index()
# print(type(stat_num))
# stat_num
# Out:
# <class 'pandas.core.series.Series'>
# 0      877
# 1      159
# 2       97
# 3       85
# 4       85
#       ...
# 129      1
# 140      1
# 183      1
# 198      1
# 272      1
# Name: num_point, Length: 75, dtype: int64

# %%
# stat = pd.merge(stat_num, stat_percent, right_index = True,left_index = True)
# stat

# %%
# stat_out_path = r'D:\Pdt_V2.0\outputs' + '/' + indicator_name + '/' + Path(input_file_path).stem

# if not os.path.exists(stat_out_path):
#     os.makedirs(stat_out_path)
    

# stat.to_excel(stat_out_path + '/' + Path(input_file_path).stem + '_stat_final.xlsx', index=True, index_label= 'Num_points_in_polygon',
#            header=['Num_Polygons','Percent'])
